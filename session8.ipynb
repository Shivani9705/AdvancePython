# %% [markdown]
# # Webscraping project

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
# ...

# %%
import requests

# %%
res=requests.get("https://www.flipkart.com/audio-video/pr?sid=0pm&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_d901052d-420a-402a-8b69-e6580de37ab3_1_X1NCR146KC29_MC.10FP40LOO0ES&cid=10FP40LOO0ES")

# %%
res
# Out:
# <Response [200]>

# %%
data=res.content

# %%
data[0:100]
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><'

# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from bs4 import BeautifulSoup

# %%
bs=BeautifulSoup(data)

# %%
# heading tag

# %%
head_tag=bs.find('h1')

# %%
head_tag
# Out:
# <h1 class="_Omnvo">Audio &amp; Video</h1>

# %%
head_tag.text
# Out:
# 'Audio & Video'

# %%
head2=bs.find_all('h2')

# %%
head2
# Out:
# [<h2 class="rcbZhR">Audio &amp; Video Price List</h2>,
#  <h2>Related Searches</h2>,
#  <h2>Trending Searches</h2>]

# %%
for i in head2:
    print(i.text)
# Out:
# Audio & Video Price List
# Related Searches
# Trending Searches

# %%
p_tag=bs.find_all('p')

# %%
p_tag
# Out:
# [<p class="qW2QI1">Great product</p>,
#  <p class="zJ1ZGa ZDi3w2">Mayur  Dharmal</p>,
#  <p class="Zhmv6U" id="review-c607999a-4390-43a5-b4ec-1af98d48c81f"><span>Certified Buyer</span></p>,
#  <p class="zJ1ZGa">Nov, 2023</p>,
#  <p class="qW2QI1">Fabulous!</p>,
#  <p class="zJ1ZGa ZDi3w2">Pʀʌɗɘɘp Mɩcʜʌɘɭ</p>,
#  <p class="Zhmv6U" id="review-4ffa0f32-4064-45ab-ac77-be075036ec7d"><span>Certified Buyer</span></p>,
#  <p class="zJ1ZGa">4 days ago</p>,
#  <p class="qW2QI1">Wonderful</p>,
#  <p class="zJ1ZGa ZDi3w2">mani shankar</p>,
#  <p class="Zhmv6U" id="review-e772f61d-dad6-4b3d-be90-3c9a64cc1502"><span>Certified Buyer</span></p>,
#  <p class="zJ1ZGa">Aug, 2024</p>,
#  <p class="qW2QI1">Not good</p>,
#  <p class="zJ1ZGa ZDi3w2">anuj  Kumar</p>,
#  <p class="Zhmv6U" id="review-49d914d4-b723-4bb8-8d3b-40f7320e65d9"><span>Certified Buyer</span></p>,
#  <p class="zJ1ZGa">20 days ago</p>,
#  <p class="qW2QI1">Worth the money</p>,
#  <p class="zJ1ZGa ZDi3w2">sanjay kumar gupta</p>,
# ...

# %%
for i in p_tag:
    print(i.text)
# Out:
# Great product
# Mayur  Dharmal
# Certified Buyer
# Nov, 2023
# Fabulous!
# Pʀʌɗɘɘp Mɩcʜʌɘɭ
# Certified Buyer
# 4 days ago
# Wonderful
# mani shankar
# Certified Buyer
# Aug, 2024
# Not good
# anuj  Kumar
# Certified Buyer
# 20 days ago
# Worth the money
# sanjay kumar gupta
# Certified Buyer
# Jul, 2022
# Awesome
# Flipkart Customer
# Certified Buyer
# 1 day ago
# Awesome
# Flipkart Customer
# Certified Buyer
# Sep, 2022
# Terrific purchase
# Rohit Mazumder
# Certified Buyer
# 1 day ago
# Terrific
# Flipkart Customer
# Certified Buyer
# Nov, 2024
# Worth the money
# karthik T
# Certified Buyer
# 3 days ago
# Speakers | Headset | Audio Accessories | Music Players Accessories | Video Accessories | Professional Audio Systems
# ...

# %%
# Extract image tag

# %%
img_tag=bs.find_all('img')

# %%
img_tag[0].get('src')
# Out:
# '//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png'

# %%
img_tag[1].get('src')
# Out:
# '//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png'

# %%
# anchor tag extract

# %%
anchor_tag=bs.find_all('a')

# %%
anchor_tag
# Out:
# [<a href="/"><img alt="Flipkart" class="TVd0Ah" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="p8iyLE" href="/plus">Explore<!-- --> <span class="stfyUS">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="ol1oIH" href="/account/login?ret=/audio-video/pr%3Fsid%3D0pm%26otracker%3Dcategorytree%26fm%3Dneo%252Fmerchandising%26iid%3DM_d901052d-420a-402a-8b69-e6580de37ab3_1_X1NCR146KC29_MC.10FP40LOO0ES%26cid%3D10FP40LOO0ES">Login</a>,
#  <a class="DDNGCa" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a>,
# ...

# %%
anchor_tag[1].get('href')
# Out:
# '/plus'

# %%
links=[]
for i in anchor_tag:
    lnk=f"https://www.facebook.com/{i.get('href')}"
    links.append(lnk)

# %%
links
# Out:
# ['https://www.facebook.com//',
#  'https://www.facebook.com//plus',
#  'https://www.facebook.com//account/login?ret=/audio-video/pr%3Fsid%3D0pm%26otracker%3Dcategorytree%26fm%3Dneo%252Fmerchandising%26iid%3DM_d901052d-420a-402a-8b69-e6580de37ab3_1_X1NCR146KC29_MC.10FP40LOO0ES%26cid%3D10FP40LOO0ES',
#  'https://www.facebook.com/https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect',
#  'https://www.facebook.com//viewcart?exploreMode=true&preference=FLIPKART',
#  'https://www.facebook.com//audio-video/pr?sid=0pm&otracker=categorytree',
#  'https://www.facebook.com//audio-video/video-accessories/pr?sid=0pm,q9n&otracker=categorytree',
#  'https://www.facebook.com//audio-video/speakers/pr?sid=0pm,0o7&otracker=categorytree',
#  'https://www.facebook.com//audio-video/music-players-accessories/pr?sid=0pm,dfp&otracker=categorytree',
#  'https://www.facebook.com//audio-video/audio-accessories/pr?sid=0pm,uvd&otracker=categorytree',
# ...

# %%
# Extract table

# %%
table_tag=bs.find_all('table')

# %%
table_tag
# Out:
# []

# %%
result=requests.get("https://www.flipkart.com/home-furnishing/bed-linen-blankets/bedsheets/pr?sid=jra,knw,qcw&marketplace=FLIPKART&otracker=nmenu_sub_Home%20%26%20Furniture_0_Bedsheets")

# %%
result
# Out:
# <Response [200]>

# %%
data=result.content

# %%
bs=BeautifulSoup(data)

# %%
bs
# Out:
# <!DOCTYPE html>
# ...

# %%
table_tag=bs.find_all('table')

# %%
table_tag[0]
# Out:
# <table>
# <tbody>
# <tr>
# <td><a href="/home-furnishing/kitchen-table-linen/kitchen-linen-sets/pr?sid=jra,iwp,glu">Kitchen Linen Sets</a></td>
# <td><a href="/home-furnishing/bed-linen-blankets/pr?sid=jra,knw">Bed Linen </a></td>
# <td><a href="/home-furnishing/bath-linen/pr?sid=jra,jk3">Bath Linen </a></td>
# <td><a href="/home-furnishing/covers-protectors/sofa-covers/pr?sid=jra,ixy,uis">Sofa Covers </a></td>
# </tr>
# <tr>
# <td><a href="/home-furnishing/curtains-accessories/curtains/pr?sid=jra,sl5,2va">Curtains</a></td>
# <td><a href="/home-furnishing/bed-linen-blankets/blankets/pr?sid=jra,knw,llw">Blankets</a></td>
# <td><a href="/home-furnishing/bath-linen/shower-curtains/pr?sid=jra,jk3,kok">Shower Curtains</a></td>
# <td><a href="/home-furnishing/kitchen-table-linen/coasters/pr?sid=jra,iwp,2pd">Coasters</a></td>
# </tr>
# <tr>
# <td><a href="/home-furnishing/floor-coverings/pr?sid=jra,kwq">Floor Coverings</a></td>
# ...

# %%
rows=[]
for row in table_tag[0].find_all('tr'):
    entry=[value.text.strip() for value in row.find_all('td')]
    rows.append(entry)

# %%
rows
# Out:
# [['Kitchen Linen Sets', 'Bed Linen', 'Bath Linen', 'Sofa Covers'],
#  ['Curtains', 'Blankets', 'Shower Curtains', 'Coasters'],
#  ['Floor Coverings', 'Table Placemats', 'Bath Towels', 'Napkins'],
#  ['Cushions', 'Bed Covers', 'Carpet Rugs', 'Aprons'],
#  ['Pillows', 'Table Linen Set', 'Mats', 'Napkin Rings']]

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.0 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.0 MB 2.2 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 2.3 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.0 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.0 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.0 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/11.0 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.0 MB 2.0 MB/s eta 0:00:04
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(rows)
# Out:
#                     0                1                2             3
# 0  Kitchen Linen Sets        Bed Linen       Bath Linen   Sofa Covers
# 1            Curtains         Blankets  Shower Curtains      Coasters
# 2     Floor Coverings  Table Placemats      Bath Towels       Napkins
# 3            Cushions       Bed Covers      Carpet Rugs        Aprons
# 4             Pillows  Table Linen Set             Mats  Napkin Rings
